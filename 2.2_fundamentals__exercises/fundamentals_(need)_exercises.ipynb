# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Fundamentals (Need) Exercises</span></div>

# %% [markdown]
# # Exercise 1

# %% [markdown]
# 1. ** ** means to bold
# 2. *...* means italic
# 3. # The largest heading
# 4. ## The second-largest heading
# 5. ### The third-largest heading
# 6. #### The smallest heading
# 7. 'print('Hello World')
# 8. [SP2273 Website](https://sps.nus.edu.sg/sp2273)
# 9. ![](data:image/jpeg;base64,...)
# 10.
# | A    |  B   |    C |
# | :--- | :--: | ---: |
# | a1   |  b1  |   c1 |
# | a2   |  b2  |   c2 |
# | a3   |  b3  |   c3 |
# 11. Fruits
#     - Apples
#     - Oranges
#     - Banana
# 1. Vegetables
#     1. Carrot
#     2. Potato
#     3. Celery
#
# 12. a \ne b
# 13. $a \lt b$
# 14. $a \leq b$
# 15. $a \gt b$
# 16. $a \geq b$
# 17. $\alpha, \beta, \gamma, \pi, \lambda$
#
# # Python features I missed
# *18. *** *** means all bold and italic*
#
# *19. hello <sub>world</sub>*
#
# *20. hello <sup>world</sup>*
#
# 21.
# $$
# x = \dfrac{-b \pm \sqrt{b^2-4ac}}{2a}
# $$
#
# 22. $\dfrac{y}{x}$
# 23. $x_{a}$
# 24. $x^{(y+z)}$
# 25. $\sqrt{a+b+c}$
# 26. $\sum_{n=1}^{n=\infty} x_n$
# 27. $\int_{x=1}^{x=\infty} f(x)dx$

# %% [markdown]
# # Exercise 2

# %%
import math         # Adding(importing) the functions
                    # of the 'math' package

# %%
x, y = 3, 4
z = math.sqrt(x*2 + y**2)
print(x, y, z)
# Out:
# 3 4 4.69041575982343

# %% [markdown]
# # Exercise 3

# %% [markdown]
# | # |  Term | Description |
# |:--|:-----:|------------:|
# | 1 |Function| It is a reusable block of code that performs a specific task|
# | 2 |Arguments |They are actual values you pass into a function when you call it|
# | 3 |Comments|They are are notes written in the code that are not executed by the program|
# | 4 |Indentations|Python uses identation to show which lines belong together|
# | 5 | Packages|A package is a collection of relatde modules that help to organise large programs and allow you to reuse code|
# | 6 | . | It is used to access attributes or functions inside modules, objects, or packages.|
# | 7 | : |It marks the start of a code block and used in statements like if, for, while, def, class.|
# | 8 | []|It is used to create or access a listand also stores multiple items in order|
# | 9 |[[],[]]| It means a list inside another list and it is used to represent tables, matrices or grouped data|
# | 10| {} |It is used for dictionaries or sets|

# %% [markdown]
# # Exercise 4

# %%
5/2           # The bracket indicates standard division.
# Out:
# 2.5

# %%
5//2          # The double bracket indicatess floor division where the value is being rounded down to the nearest integer towards negative infinity.
# Out:
# 2

# %%
5%2           # The % operator calculates and returns the remainder of a divison
# In this case, it is 5 divided by 2 equals 2 with a remainder of 1
# Out:
# 1
