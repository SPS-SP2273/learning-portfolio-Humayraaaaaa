# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Storing Data (Need) Exercises</span></div>

# %%
import numpy as np

# %% [markdown]
# ### Exercise 1

# %% [markdown]
# Two differences:
# 1. Lists uses python while arrays uses Numpy
#
# *2. Arrays are fussy about type*
#
# *Arrays can add a number, add another list, multiplying by a number, squaring, asking questions, size and mathematics*
#
# Two similarities
# 1. Lists and arrays involves listing of elements and storing information within a square bracket.
# 2. Order between elements in the list and array matters
#
# Meaning of dictionary
#
# *Dictionaries hold data (values) paired with a key. i.e. you can access the value using the real name as a key.*

# %% [markdown]
# ### Exercise 2

# %%
py_list = ["a1", "b2", "c3", "d4", "e5", "f6", "g7", "h8", "i9", "j10"]


print(py_list[0])   # Prints 'a1'
print(py_list[2])   # Prints 'c3'
print(py_list[4])   # Prints 'e5'
print(py_list[6])   # Prints 'g7'
print(py_list[8])   # Prints 'i9'
# Out:
# a1
# c3
# e5
# g7
# i9

# %% [markdown]
# ### Exercise 3

# %%
elements = ['Hydrogen',
            'Helium', 'Lithium',
            'Beryllium', 'Boron', 'Carbon',
            'Nitrogen', 'Oxygen',
            'Fluorine',
            'Neon']

# %%
elements[5]
# Out:
# 'Carbon'

# %%
elements[-5]
# Out:
# 'Carbon'

# %% [markdown]
# ### Exercise 4

# %%
numbers=[45, 60, 1, 30, 96, 1, 96, 57, 16, 1,
        99, 62, 86, 43, 42, 60, 59, 1, 1, 35,
        83, 47, 34, 28, 68, 23, 22, 92, 1, 79,
        1, 29, 94, 72, 46, 47, 1, 74, 32, 20,
        8, 37, 35, 1, 89, 29, 86, 19, 43, 61]  
np_array = np.array(numbers)

# %%
np_array == 1
my_mask = np_array == 1
np_array[my_mask]
count = sum(my_mask)
print(count)
# Out:
# 9

# %%
np_array == 1
my_mask = np_array == 1
np_array[my_mask]
sum(np_array[my_mask])
# Out:
# np.int64(9)

# %% [markdown]
# ### Exercise 5

# %%
x_1 = [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]
x_2 = [1, 8, 27, 64, 125, 216, 343, 512, 729, 1000]

# %%
py_list = [x_1, x_2]
np_array = np.array(py_list)

# %%
np.mean(py_list)
# Out:
# np.float64(38.5)

# %%
np.std(py_list)
# Out:
# np.float64(32.41990129534635)

# %%
def pearson_correlation(x_1,x_2):
    x_1 = np.array(x_1)
    x_2 = np.array(y)

# %%
def pearson_correlation(x_1,x_2):
    x_1 = np.array(x_1)
    x_2 = np.array(x_2)
np.mean(x_1)                  # mean of x_1
np.mean(x_2)                  # mean of x_2
dev_x_1 = x_1 - np.mean(x_1)      # deviations from mean of x_1
dev_x_2 = x_2 - np.mean(x_2)      # deviations from mean of x_2
numerator = np.sum(dev_x_1 * dev_x_2)       # Calculate the numerator (sum of the product of deviations)

# Calculate the denominator (square root of the product of the sum of squared deviations)
sum_sq_dev_x_1 = np.sum(dev_x_1**2)
sum_sq_dev_x_2 = np.sum(dev_x_2**2)
denominator = np.sqrt(sum_sq_dev_x_1 * sum_sq_dev_x_2)

if denominator == 0:
    return 0

r = numerator / denominator
    
return r

x_1 = [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]
x_2 = [1, 8, 27, 64, 125, 216, 343, 512, 729, 1000]

correlation_coefficient = pearson_correlation(x_1, x_2)
print(f"The Pearson correlation coefficient is: {correlation_coefficient}")
# Out:
#   Cell In[19], line 16
#     return 0
#     ^
# SyntaxError: 'return' outside function

# %%
import numpy as np

def pearson_correlation(x_1, x_2):
    x_1 = np.array(x_1)
    x_2 = np.array(x_2)

    mean_x_1 = np.mean(x_1)
    mean_x_2 = np.mean(x_2)

    dev_x_1 = x_1 - mean_x_1
    dev_x_2 = x_2 - mean_x_2

    numerator = np.sum(dev_x_1 * dev_x_2)

    sum_sq_dev_x_1 = np.sum(dev_x_1**2)
    sum_sq_dev_x_2 = np.sum(dev_x_2**2)
    denominator = np.sqrt(sum_sq_dev_x_1 * sum_sq_dev_x_2)

    if denominator == 0:
        return 0

    r = numerator / denominator
    return r


x_1 = [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]
x_2 = [1, 8, 27, 64, 125, 216, 343, 512, 729, 1000]

correlation_coefficient = pearson_correlation(x_1, x_2)
print(f"The Pearson correlation coefficient is: {correlation_coefficient}")
# Out:
# The Pearson correlation coefficient is: 0.9871796626270701

# %%
np.corrcoef(py_list)
# Out:
# np.float64(1.0)

# %% [markdown]
# When doing it manually, the Pearson correlation coefficient has a more specific value compared to the np.corrcoef method.
