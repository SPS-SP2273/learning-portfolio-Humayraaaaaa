# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Fundamentals (Good)</span></div>

# %% [markdown]
# # What to expect in this chapter

# %% [markdown]
# # 1 There is more to if

# %%
name = 'Batman'

if name == 'Batman':
    print('Hello Batman!')
elif name == 'Robin':
    print('Hello Sidekick!')
else:
    print('Hello World!')
# Out:
# Hello Batman!

# %%
name = "batman"
universe = 'marvel'

if name == 'batman':
    if universe =='dc':
        print('batman is the best of dc')
    else:
        print('Hello batman')
# Out:
# Hello batman

# %% [markdown]
# # 2 Asking questions

# %%
fruits = ['apple', 'banana', 'pineapple', 'jackfruit']
vegetables = ['celery', 'potato', 'broccoli', 'kale']

# %%
'apple' in fruits and 'celery' in vegetables
# Out:
# True

# %%
'celery' not in fruits
# Out:
# True

# %%
for fruit in fruits:
    if 'e' in fruit:
        print(fruit)
# Out:
# apple
# pineapple

# %% [markdown]
# ## 2.1 Asking Math questions

# %%
x=3
x > 5 and x < 15
# Out:
# False

# %%
5 < x < 15
# Out:
# False

# %%
(x > 5) and (x < 15)
# Out:
# False

# %%
x = int(1.234)
print(x, type(x))
# Out:
# 1 <class 'int'>

# %%
x = 1.234
print(x, type(x))
# Out:
# 1.234 <class 'float'>

# %% [markdown]
# x is a number

# %%
x = str(1.234)
print(x, type(x))
# Out:
# 1.234 <class 'str'>

# %% [markdown]
# x is a english word that looks like a number

# %% [markdown]
# length of a string is not the same as the length of an integer

# %%
x = float(1.234)
print(x, type(x))

# %%
x = complex(1.234)
print(x, type(x))
# Out:
# (1.234+0j) <class 'complex'>

# %% [markdown]
# # 3 Python stores information in different formats or types

# %% [markdown]
# # 4 Never compare floats directly

# %%
a = 0.1
a3 = 0.3
a * 3 == a3
# Out:
# False

# %%
f'{0.3:.17f}'
# Out:
# '0.29999999999999999'

# %% [markdown]
# ## 4.1 The Problem

# %%
a = .1

a3 = .3

ax3 == a3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 5
#       1 a = .1
#       3 a3 = .3
# ----> 5 ax3 == a3
#
# NameError: name 'ax3' is not defined

# %%
print(f'(a=:.17f) and a3=:.19f)')
# Out:
# (a=:.17f) and a3=:.19f)

# %%
(3+a a3) < 1E - 10
# Out:
#   Cell In[23], line 1
#     (3+a a3) < 1E - 10
#                ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# ## 4.2 A solution

# %%
eps = 1E-10
abs(a * 3 - a3) < eps
# Out:
# True

# %%
np.isclose(a * 3, a3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 np.isclose(a * 3, a3)
#
# NameError: name 'np' is not defined

# %%
import numpy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 import numpy
#
# ModuleNotFoundError: No module named 'numpy'

# %%
text = 'test' 
f'{text}'
# Out:
# 'test'

# %%
x = 40
y = x +2 
y
# Out:
# 42

# %%
x= 4000
x = x+2
x
# Out:
# 4002

# %% [markdown]
# # 5 Combining English and variables

# %% [markdown]
# ## 5.1 Structure of f-strings

# %%
x, y= 42, 24
print(f'{x=} and {y=}')
# Out:
# x=42 and y=24

# %%
x, y= 42/5, 24/5
print(f'{x=:.3f} and {y=:.6f}')
# Out:
# x=8.400 and y=4.800000

# %%
name = "Batman"
print(f"Hello {name}!")
# Out:
# Hello Batman!

# %%
name = "Batman"
print(f"Hello {name.upper()}!")
# Out:
# Hello BATMAN!

# %%
x = 10
print(f"The value of {x} squared is {x**2}!")
# Out:
# The value of 10 squared is 100!

# %% [markdown]
# # 6 Escape sequences

# %% [markdown]
# ## 6.1 Self-documenting f-strings

# %%
x = 40
y = x + 2

# %%
y = 40
y = y + 2
print(y)
# Out:
# 42

# %%
x = y = 10

# %% [markdown]
# # 7 Computers read = from Right to Left!

# %%
y = 40
y = y + 2
y
y = 40
y += 2    # Same as y = y + 2
y
# Out:
# 42

# %% [markdown]
# # 8 Shorter and Cleaner Code

# %%
YEARS = 1

student_age = 27*YEARS

# %% [markdown]
# # 9 Python can be a prima-donna.

# %%
print

# %% [markdown]
# # 10 Best Practices for Scientific Computing

# %%
try:
    score = float(input("Enter the student's score: "))

    if score < 0 or score > 100:
        print("Error: Please enter a score between 0 and 100.")
    elif score >= 70:
        print("The student's letter grade is: A")
    elif score >= 50:
        print("The student's letter grade is: B")
    elif score >= 35:
        print("The student's letter grade is: C")
    else:
        print("The student's letter grade is: Fail")

except ValueError:
    print("Error: Please enter a valid numerical value.")
# Out:
# Error: Please enter a valid numerical value.

# %% [markdown]
# # 11 Looking for help

# %% [markdown]
# ## References

# %% [markdown]
# ## Footnotes

# %%
x = '123'
y = 123
z = 123.0

# %%
print(x*3)
print(y*3)
print(z*3)
# Out:
# 123123123
# 369
# 369.0

# %%
print(int(z))
# Out:
# 123

# %%
print(z)
# Out:
# 123.0
