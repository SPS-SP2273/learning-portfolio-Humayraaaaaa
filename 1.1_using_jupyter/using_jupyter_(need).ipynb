# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Using Jupyter (Need)</span></div>

# %% [markdown]
# # What to expect in this chapter

# %% [markdown]
# # 1 Getting ready

# %%
print('hello world')
# Out:
# hello world

# %%
print('test')
# Out:
# test

# %% [markdown]
# print('Hello world')d

# %%
# %timeit x=10
# Out:
# 30.6 ns ± 3.47 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
# %timeit x=10**2
# Out:
# 29.7 ns ± 4.46 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# # 2 Getting started with Jupyter

# %% [markdown]
# ## 2.1 It is all about running cells

# %% [markdown]
# ## 2.2 A traditional start

# %% [markdown]
# # 3 All about Markdown

# %% [markdown]
# The ships hung in the sky in much the same way that bricks don't

# %% [markdown]
# ## 3.1 Rendering Markdown cells

# %% [markdown]
# The ships hung in the sky in much the same way that bricks don't

# %% [markdown]
# ## 3.2 Some basic syntax

# %% [markdown]
# The ships *hung in the sky* in much the same way that **bricks don't.** <sup>1</sup><sub>QUOTE</sub>

# %% [markdown]
# ## 3.3 Headings

# %% [markdown]
# # The largest heading

# %% [markdown]
# ## The second largest heading

# %% [markdown]
# ### The third largest heading

# %% [markdown]
# #### The smallest heading

# %% [markdown]
# ## 3.4 Displaying Code

# %%
`print('Hello World!')`
# Out:
#   Cell In[4], line 1
#     `print('Hello World!')`
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 3.5 Links

# %% [markdown]
# [NUS Mods website] (https://nusmods.com/timetable/sem-1)

# %% [markdown]
# ## 3.6 Images

# %% [markdown]
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSbvCFFFCsQYbI82fOx2Tv9GHGxS2DQa34geg&s)

# %% [markdown]
# ![](data:image/jpeg;base64,...)

# %% [markdown]
# ## 3.7 Tables

# %% [markdown]
# | A   |  B   |   C |
# | :---|:--:  |---: |
# | a1  |  b1  |   c1|
# | a2  |  b2  |   c2|
# | a3  |  b3  |   c3|

# %% [markdown]
# ## 3.8 Lists

# %% [markdown]
# 1. Master Yoda
# 1. Luke Skywalker
# 1. Anakin Skywalker

# %% [markdown]
# - Master Yoda
# - Luke Skywalker
# - Anakin Skywalker

# %% [markdown]
# 1. Was a Jedi
#    1. Was a bit green
# 1. Luke Skywalker
#    1. Was a Jedi
#    1. Is Anakin's son.
# 1. Anakin Skywalker
#    1. Was a Jedi then became a baddie
#    1. Is famous for saying 'Luke, I am your father'

# %% [markdown]
# ## 3.9 Equations

# %% [markdown]
# $\sqrt{b^2-4ac}$

# %% [markdown]
# $$
# x = \dfrac{-b\pm \sqrt{b^2-4ac}}{2a}
# $$

# %% [markdown]
# $\dfrac{y}{x}$

# %% [markdown]
# $x_{a}$

# %% [markdown]
# $x^{(y+z)}$

# %% [markdown]
# $\sqrt{a+b+c}$

# %% [markdown]
# 	$\sum_{n=1}^{n=\infty} x_n$

# %% [markdown]
# $\int_{x=1}^{x=\infty} f(x)dx$

# %% [markdown]
# $a \ne b$

# %% [markdown]
# $a \lt b$

# %% [markdown]
# $a \leq b$

# %% [markdown]
# $a \gt b$

# %% [markdown]
# $a \geq b$

# %% [markdown]
# $\alpha, \beta, \gamma, \pi, \lambda$

# %% [markdown]
# ## Footnotes
