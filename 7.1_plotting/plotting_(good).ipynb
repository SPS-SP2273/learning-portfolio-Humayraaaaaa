# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Good)</span></div>

# %% [markdown]
# # What to expect in this chapter

# %%
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# # 1 Some nomenclature

# %% [markdown]
# # 2 Comparing the two ‘dialects’

# %% [markdown]
# ### pyplot Interface

# %%
# Your code here
x = np.linspace(-np.pi, np.pi, num=100)
cos_x = np.cos(x)
sin_x = np.sin(x)

# %%
plt.plot(x, cos_x, label='cos x')
plt.plot(x, sin_x, label='sin x')
plt.legend()

# %% [markdown]
# ### OO Interface

# %%
# Your code here
fig, ax = plt.subplots(nrows=1, ncols=1)
ax.plot(x, cos_x, label='cos x')
ax.plot(x, sin_x, label='sin x')
ax.legend()

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, sharey=True)
ax[0].plot(x, cos_x, label='cos x')
ax[1].plot(x, sin_x, label='sin x')
for a in ax:
    a.legend
    a.grid(alpha=.5)

plt.tight_layout()

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, sharey=True)
ax[0].plot(x, cos_x, label='cos x')
ax[1].plot(x, sin_x, label='sin x')
for a in ax:
    a.legend(loc='lower right')
    a.grid(alpha=.5)

ax[0].set_title('HAHAHAH')
ax[1].set_title('WHOOOOO')

plt.tight_layout()

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, sharey=True, sharex=True)
ax[0,0].plot(x, cos_x, label='cos x')
ax[0,1].plot(x, sin_x, label='sin x')
for a in ax.flatten():
    print('----',a)
    a.legend(loc='lower right')
    a.grid(alpha=.5)

ax[0,0].set_title('HAHAHAH')
ax[0,1].set_title('WHOOOOO')

plt.tight_layout()
# Out:
# ---- Axes(0.125,0.53;0.352273x0.35)
# ---- Axes(0.547727,0.53;0.352273x0.35)
# ---- Axes(0.125,0.11;0.352273x0.35)
# ---- Axes(0.547727,0.11;0.352273x0.35)
# C:\Users\65881\AppData\Local\Temp\ipykernel_29052\2441228553.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   a.legend(loc='lower right')

# %% [markdown]
# jpeg --> smaller in size
# opening and closing might lose the changes
# pdf is not pixelated when you zoom in
# alternatively, increase the dpi to make it clear when zooming in

# %% [markdown]
# # 3 What is OO ax, really?

# %%
fig, ax = plt.subplots(nrows=2, ncols=1)

ax[0].plot(x, cos_x, label='cos x')
ax[1].plot(x, sin_x, label='sin x')

ax[0].legend()
ax[1].legend()

# %%
fig, ax = plt.subplots(ncols=1, nrows=2)

# %% [markdown]
# # 4 A complete OO example

# %%
fig, ax = plt.subplots(nrows=2, ncols=1,
                       figsize=(5, 5),
                       sharex=True)
ax[0].plot(x, cos_x, label=r'$\cos(x)$')
ax[0].fill_between(x, 0, cos_x, alpha=.25)
ax[1].plot(x, sin_x, label=r'$\sin(x)$')
ax[1].fill_between(x, 0, sin_x, alpha=.25)

for a in ax:
    a.legend()
    a.grid(alpha=.25)
    a.set_ylabel('$y$', rotation=0)

ax[1].set_xlabel('$x$')

fig.suptitle(r'$\sin(x)$ and $\cos(x)$')
fig.tight_layout()

# %% [markdown]
# # 5 Multiple rows and columns

# %%
fig, ax = plt.subplots(nrows=2, ncols=2,
                       figsize=(5, 5),
                       sharex='col', sharey='col')

# Some variables to access the axes and improve readabilty
top_left, top_right, bottom_left, bottom_right = ax.flatten()

top_left.set_title('Top Left')
top_right.set_title('Top Right')
bottom_left.set_title('Bottom Left')
bottom_right.set_title('Bottom Right')

top_left.hlines(y=1, xmin=0, xmax=4)
top_right.hlines(y=2, xmin=0, xmax=5)
bottom_left.hlines(y=3, xmin=0, xmax=4)
bottom_right.hlines(y=4, xmin=0, xmax=5)

for a in ax.flatten():
    a.grid(alpha=.25)

plt.tight_layout()

# %% [markdown]
# ### Using ax

# %%
# Your code here
fig, ax = plt.subplots(nrows=2, ncols=2,
                       figsize=(5, 5),
                       sharex='col', sharey='row')
ax[0, 0].set_title('Top Left')
ax[0, 1].set_title('Top Right')
ax[1, 0].set_title('Bottom Left')
ax[1, 1].set_title('Bottom Right')

top_left=ax[0, 0]
top_right=ax[0, 1]
bottom_left=ax[1, 0]
bottom_right=ax[1, 1]

# %%
ax[0, 0].set_title('Top Left')
ax[0, 1].set_title('Top Right')
ax[1, 0].set_title('Bottom Left')
ax[1, 1].set_title('Bottom Right')
# Out:
# Text(0.5, 1.0, 'Bottom Right')

# %%
import pandas as pd

# %%
pd.read_csv

# %% [markdown]
# ## 5.1 Sharing axes

# %% [markdown]
# ## 5.2 Accessing all axes

# %% [markdown]
# # 6 Other useful plots

# %% [markdown]
# ## 6.1 Histograms

# %% [markdown]
# ### Data

# %%
# Your code here

# %% [markdown]
# ### A quick helper function

# %%
# Your code here

# %% [markdown]
# ### The histogram

# %%
# Your code here

# %% [markdown]
# ## 6.2 Scatter plots

# %% [markdown]
# ## 6.3 Bar charts

# %% [markdown]
# ## 6.4 Pie charts
