# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Using Jupyter (Good), Exercises</span></div>

# %%
while True:
    print('*', end='')

# %%
print = 'PRINT'

# %%
print('Hello World')

# %%
squares = [i**2 for i in range(10)]

# %%
squares = list()
for i in range(10):
    squares.append(i**2)

# %%
print = 'Print'

# %%
squares = [i**2 for i in range(10)]

# %%
squares = list()
for i in range(10):
    squares.append(i**2)

# %%
# %%timeit
squares = [i**2 for i in range(10)]
# Out:
# 1.28 μs ± 88.1 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
# %%timeit
squares = list()
for i in range(10):
    squares.append(i**2)
# Out:
# 1.7 μs ± 303 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## Footnotes

# %%
import math
import numpy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 2
#       1 import math
# ----> 2 import numpy
#
# ModuleNotFoundError: No module named 'numpy'

# %%
math, sqrt(2+2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 math, sqrt(2+2)
#
# NameError: name 'sqrt' is not defined

# %%
(1+1)=(10+3)
# Out:
#   Cell In[12], line 1
#     (1+1)=(10+3)
#      ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
print('hahahaah', 'wowoowowoww', sep='xxxxx', end= 'mmmmmm')
# Out:
# Running cells with 'base (Python 3.13.11)' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'conda install -n base ipykernel --update-deps --force-reinstall'
